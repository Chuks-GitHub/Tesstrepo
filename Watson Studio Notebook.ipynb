# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Godday Omoile

# %% [markdown]
# Future Data scientist

# %% [markdown]
# _I am interested in data science because it is one of the fastest growing field in high demand with promising career prospect_.

# %% [markdown]
# ### Simple Maths

# %%
50*2/10
# Out:
# 10.0

# %% [markdown]
# -  1     One
# -  2     Two
# -  3     Three
# -  4     Four
# -  5     Five
# ___
# SN             FRUITS                  VITAMIN
# 1.             Apple                   Vitamin C
# ___
# 2.             Orange                  Vitamin C
# ___
# 3.             Pineapple               Vitamin C
# ___
# 4.             Carot                   Vitamin A
# ___
# 5.             Watermellon             Vitamin C
# ___
#
#
# #### Calculation
#
#  Ma = Mb * Vb
#  ___
#         Va
